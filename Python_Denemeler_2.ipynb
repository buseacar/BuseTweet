# %% [markdown]
# <a href="https://colab.research.google.com/github/buseacar/BuseTweet/blob/main/Python_Denemeler_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='11'
print(a)
print(type(a))
# Out:
# 11
# <class 'str'>

# %%
a=int(a)
print(a)
print(type(int(a)))
# Out:
# 11
# <class 'int'>

# %%
b='x'
print(b)
print(type(b))
# Out:
# x
# <class 'str'>

# %%
b=int(b)  # bilinmeyen int olamaz hata verir

# %%
x=[14,25.5, 'yalova', ['ankara','london','paris','washington']]

# %%
x
# Out:
# [14, 25.5, 'yalova', ['ankara', 'london', 'paris', 'washington']]

# %%
x[-1][0:2]='istanbul','new york'

# %%
x
# Out:
# [14, 25.5, 'yalova', ['istanbul', 'new york', 'paris', 'washington']]

# %%
x[-1][-1:3]='one','two','three','four'# (-) olunca sondaki -1 diğerleri yine de sağdan sayılıyor

# %%
x
# Out:
# [14,
#  25.5,
#  'yalova',
#  ['istanbul',
#   'new york',
#   'paris',
#   'bir',
#   'iki',
#   'üç',
#   'dört',
#   'one',
#   'two',
#   'three',
#   'four',
#   'washington']]

# %%
x[:]
# Out:
# [14,
#  25.5,
#  'yalova',
#  ['istanbul',
#   'new york',
#   'paris',
#   'bir',
#   'iki',
#   'üç',
#   'dört',
#   'one',
#   'two',
#   'three',
#   'four',
#   'one',
#   'two',
#   'three',
#   'four',
#   'washington']]

# %%
x[1:] #1. eleman hariç
# Out:
# [25.5,
#  'yalova',
#  ['istanbul',
#   'new york',
#   'paris',
#   'bir',
#   'iki',
#   'üç',
#   'dört',
#   'one',
#   'two',
#   'three',
#   'four',
#   'one',
#   'two',
#   'three',
#   'four',
#   'washington']]

# %%
x[2,3] #sayıları sıralı seçebilir bunu yapamaz
